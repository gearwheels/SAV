# %%
import numpy as np
def f(y, t, params):
    y1, y2 = y
    a, b, c, d = params
    return [y1*(a - b * y2),
            y2 * (-c + d * y1)]   
t = np.linspace(0, 7, 71)
y0 = [2, 1]
plt = plot(0)
sol = []
var("y1, y2")
colors = ["purple", "red", "yellow"]
for i, b in enumerate(range(4, 1, -1)):
    a, c, d = 3, 1, 1
    f = [y1 * (a - b * y2), y2 * (-c + d * y1)]
    sol = desolve_odeint(f, y0, t, dvars = [y1, y2])
    plt += line(sol, color = colors[i])
show(plt)
# Out:
# Graphics object consisting of 4 graphics primitives
