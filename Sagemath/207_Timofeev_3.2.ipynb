# %%
var("y1 y2 y3 y4 t")
tmax = 1.41
alpha = pi/4
v0 = 10.0
y0 = [0, 0, v0 * cos(alpha), 0, v0 * sin(alpha)]
k = 0.01
g = 9.81
ode = [y2, -k * y2 * sqrt(y2 ^ 2 + y4 ^ 2), y4, -k * y4 * sqrt(y2 ^ 2 + y4 ^ 2) - g]
solution = desolve_system_rk4(des = ode, vars = [y1, y2, y3, y4], ics = y0, ivar = t, step = 0.01, end_points = tmax)
arr_plt = plot([])
for i in range(len(solution) - 1):
    arr_plt += line([[solution[i][1], solution[i][3]], [solution[i + 1][1], solution[i + 1][3]]])
show(arr_plt)
# Out:
# Graphics object consisting of 141 graphics primitives
